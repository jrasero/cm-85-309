# %% [markdown]
# # 1- Introduction

# %% [markdown]
# R is an open-source programming language, meaning that users can contribute packages that make our lives easier, and we can use them for free.

# %% [markdown]
# For a first impression of what R can do, let's draw 1000 random numbers following the normal distribution (`rnorm` = random normal) and plots them. R has a built-in function, called `plot` for this:

# %%
plot(rnorm(1000))
# Out:
# plot without title

# %% [markdown]
# The normal distribution is a special case of the distribution called "gaussian" with mean (average location)=1 and standard deviation (average dispersion) = 0. The gaussian distribution has a bell shape, as you can see below using the R function `hist` that displays a histogram. You'll run into this kind of distribution many times throughout the course, as it is one the most important distributions:

# %%
hist(rnorm(1000))
# Out:
# Plot with title “Histogram of rnorm(1000)”

# %% [markdown]
# One of the simplest possible tasks in R is to enter an arithmetic expression and receive a result (The second line is the answer from the machine.)

# %%
2+2
# Out:
# [1] 4

# %% [markdown]
# So the machine knows that 2 plus 2 makes 4. Of course, it also knows how to do other standard calculations. For example:

# %%
log(10)
# Out:
# [1] 2.302585

# %%
rnorm(15)
# Out:
#  [1]  1.2706788 -1.1861852  2.0058846 -0.1342522 -0.5393298  0.6465168
#  [7]  0.3412100  0.5742320 -0.3948957  0.3050348 -1.0388935 -1.0505800
# [13]  0.5155936  1.2373440 -1.5333540

# %% [markdown]
# # 2-Assigments

# %% [markdown]
# You will quickly need to store intermediate results, so that you do not have to key them in over and over again.
# R, like other computer languages, has symbolic variables, that is names that can be used to represent values.

# %% [markdown]
# To assign the value 2 to the variable x, you can enter:

# %%
x<-2

# %% [markdown]
# "<-" should be read as a single symbol: an arrow pointing to the variable to which the value is assigned. This is known as the **assignment** operator. Spacing around operators is generally disregarded by R,
#
# *N.B.* Adding a space in the middle of "<-" changes the meaning to “less than” followed by “minus” (conversely, omitting the space when comparing a variable to a negative number has unexpected consequences!).

# %%
x
# Out:
# [1] 2

# %% [markdown]
# # 3- Data types
#
#
# R has 6 basic data types, some of which we have already skimmed over:
#
# - **character**: e.g. "a", "hola", etc.
# - **numeric** (real or decimal): 3, 3.1415, -10, etc.
# - **integer**: 3L (The L specifies this variable to be an integer)
# - **logical**: TRUE or FALSE
# - **complex**: 1+2i
#
# In case of doubt about the data type, R provides built-in functions to inspect this, for example, `class` and `typeof`.

# %%
class("a")
typeof("a")
# Out:
# [1] "character"
# [1] "character"

# %%
class(3)
typeof(3)
# Out:
# [1] "numeric"
# [1] "double"

# %%
class(3L)
typeof(3L)
# Out:
# [1] "integer"
# [1] "integer"

# %%
class(TRUE)
typeof(TRUE)
# Out:
# [1] "logical"
# [1] "logical"

# %% [markdown]
# # 4- Functions

# %% [markdown]
# The way calculations are done in an encapsulated way is through the use of **functions**. For example, R has the following built-in functions, `sqrt` and `abs`, designed to compute the square root and absolute value of an input value.

# %%
sqrt(25)
# Out:
# [1] 5

# %%
abs(-5)
# Out:
# [1] 5

# %% [markdown]
# When we use a function to do something, we generally refer to this as **calling** the function, and the values that we type into the function (there can be more than one) are referred to as the **arguments** of that function.

# %% [markdown]
# ## 4.1 - Function arguments, their names and their defaults

# %% [markdown]
# There’s two more fairly important things that you need to understand about how functions work in
# R, and that’s the use of “named” arguments, and default values” for arguments. To understand what these two concepts are all about, let's introduce the function `round`, which can be used to round some value to the nearest whole number.

# %%
round(3.1415)
# Out:
# [1] 3

# %% [markdown]
# This function allows you to input a second argument to the function that specifies the number of decimal places that you want to round the number to.

# %%
round( 3.14165, 2)
# Out:
# [1] 3.14

# %% [markdown]
# The first argument is the number that needs to be rounded (i.e., 3.1415) and the second argument is the number of decimal places that it should be rounded to (i.e., 2 ). Both arguments are separated by a **comma**.
#
# In this simple example, it’s quite easy to remember which one argument comes first and which one comes second, but for more complicated functions this is not easy. Fortunately, most R functions make use of argument names.
#
# For the `round` function, the number that needs to be rounded is specified using the x argument, and the
# number of decimal points that you want it rounded to is specified using the digits argument. Because
# we have these names available to us, we can specify the arguments to the function by name.

# %%
round( x=3.14165, digits = 2) # Note that for arguments we use "="
# Out:
# [1] 3.14

# %% [markdown]
# **N.B.** When specifying the arguments using their names, it doesn’t matter what order you type them in. However, if you don’t use the argument names, then you have to input the arguments in the correct order:

# %%
round( 3.14165, 2 )
round( x = 3.1415, digits = 2 )
round( digits = 2, x = 3.1415 )
# Out:
# [1] 3.14
# [1] 3.14
# [1] 3.14

# %% [markdown]
# Finally, most of the functions have arguments with DEFAULT values, that is, arguments that if not specified, they take a particular value. In our example, 0 was the default value for digits.

# %% [markdown]
# ### Function help
#
# **Important:** In case of doubt about the name of the arguments, you can always look at the documentation the function by executing the name of function (without parenthesis) with symbol "?" prepended:

# %%
?round

# %% [markdown]
# # 5- Data Structures
#
# Let's see what data structures R includes. Data structures are a way of organizing, managing and storing data.

# %% [markdown]
# ## 5.1 - Vectors
#
# Vectors are just variables that that can store multiple values. One specific feature of vectors is that their elements must be of the same data type.

# %% [markdown]
# ### 5.1.1 - Initilization
#
# This is done all by type all the values you want to store separated by a inside the combine function, `c`

# %%
myvector<-c(1,2,3,4)
myvector
# Out:
# [1] 1 2 3 4

# %% [markdown]
# ### 5.1.2 - Accesing individual elements
#
# You can always access any individual element of a vector by using "[]" and the number of the index corresponding to the element position you want to retrieve the information from

# %%
myvector[1] # this gives the first element
myvector[2] # this gives the second element
myvector[3] # this gives the third element
myvector[4] # this gives the fourth element
# and so on...
# Out:
# [1] 1
# [1] 2
# [1] 3
# [1] 4

# %% [markdown]
# Obviously, if you try to access an element that does not exist in the vector, then you'll get a Not a Number

# %%
myvector[5]
# Out:
# [1] NA

# %% [markdown]
# ### 5.1.3 - Changing a vector
#
# You may want to change the values stored in a particular vector element. It's actually very easy:

# %%
myvector[2]<-100
myvector
# Out:
# [1]   1 100   3   4

# %% [markdown]
# ### 5.1.4 - Indexing

# %% [markdown]
# #### Indexing by index number
#
# Like an accessing operation, but we pass a vector with the indexes of the elements we want to extract. For example:

# %%
myvector[c(1,2)]
# Out:
# [1]   1 100

# %%
myvector[c(1,4)]
# Out:
# [1] 1 4

# %% [markdown]
# Note that elements will be returned according to the order of the vector supplied:

# %%
myvector[c(2,1)]
# Out:
# [1] 100   1

# %%
myvector[1:4]
# Out:
# [1]   1 100   3   4

# %% [markdown]
# #### Logical indexing
#
# We can also select elements of a vector that satisfy a particular condition. This is called logical indexing

# %%
myvector
# Out:
# [1]   1 100   3   4

# %%
myvector[myvector>10]
# Out:
# [1] 100

# %%
myvector[myvector == 4]
# Out:
# [1] 4

# %% [markdown]
# ### 5.1.5- Operations to vectors
#
# You can always alter all elements of a vector at once by applying operations like addition, substraction, multiplication and divisions

# %%
# Add 1
myvector + 1
# Substracte 1
myvector -2
# Multiply by 10
myvector*10
# Divide by 5
myvector/5
# Out:
# [1] 2 3 4 5
# [1] -1  0  1  2
# [1] 10 20 30 40
# [1] 0.2 0.4 0.6 0.8

# %% [markdown]
# You can also perform the above operatations between vectors:

# %%
myvector + (3*myvector)
# Out:
# [1]  4  8 12 16

# %% [markdown]
# ### 5.1.6 - Handy functions
#
# - `length`: it yields the number of elements in the vector:

# %%
length(myvector)
# Out:
# [1] 4

# %% [markdown]
# - `lapply`: It allows you apply a certain function to each element of a vector. It returns a list (see below).

# %%
# This applies a log function to each element of the vector
lapply(myvector, log)
# Out:
# [[1]]
# [1] 0
#
# [[2]]
# [1] 0.6931472
#
# [[3]]
# [1] 1.098612
#
# [[4]]
# [1] 1.386294

# %% [markdown]
# - `sapply`: The same as `lapply`, but it coerces the output to a vector.

# %%
# Same as above, but as a vector 
sapply(myvector, log)
# Out:
# [1] 0.0000000 0.6931472 1.0986123 1.3862944

# %%
# This is the same as using the log function
log(myvector)
# Out:
# [1] 0.0000000 0.6931472 1.0986123 1.3862944

# %% [markdown]
# Obviously the above result could be obtained just passing the vector to the `log` function, but both `lapply` and `sapply` functions can be very handy for applying complex functions, for example:

# %%
# Let's see the documentation of this function again
?sapply

# %%
sapply(c(1:length(myvector)), function(x) sqrt(x**2 + 1))
# Out:
# [1] 1.414214 2.236068 3.162278 4.123106

# %% [markdown]
# ## 5.2 - Matrix
#
# Matrices are just a bidimemnsional version of vectors, i.e. it has rows and columns. Like with vectors, the elements of a matrix must be of the same data type.
#
# In addition, most of the rules that apply to vectors also apply to vectors.

# %% [markdown]
# ### 5.2.1 - Initilization
#
# A matrix can be initialized with function `matrix`

# %%
# Arrange the above vector's 4 elements into a 2x2 matrix 
mymatrix<-matrix(myvector, nrow = 2, ncol=2)
mymatrix
# Out:
#      [,1] [,2]
# [1,] 1    3
# [2,] 2    4

# %% [markdown]
# Another way of crating a matrix is by converting data to a matrix using the the function `as.matrix`

# %%
as.matrix(myvector)
# Out:
#      [,1]
# [1,] 1
# [2,] 2
# [3,] 3
# [4,] 4

# %% [markdown]
# ### 5.2.2- Some handy functions

# %% [markdown]
# - `nrow`: it gives the number of rows
# - `ncol`: it gives the number of columns
# - `dim`:  it provides the number both the number or rows and columns

# %%
nrow(mymatrix)
ncol(mymatrix)
dim(mymatrix)
# Out:
# [1] 2
# [1] 2
# [1] 2 2

# %%
dim(as.matrix(myvector))
# Out:
# [1] 4 1

# %% [markdown]
# ## 5.3 - Factors
#
# Factors are kind of data structrure similar to vectors, but with the difference that each value has a distint label. As a result, they are useful with **nominal** data.

# %% [markdown]
# ### 5.3.1 - Initilization
#
# Factors are created using the `factor()` function.

# %%
# This is a group 
group.factor <- factor(c(1,1,1,2,2,2,3,3,3))
group.factor
# Out:
# [1] 1 1 1 2 2 2 3 3 3
# Levels: 1 2 3

# %% [markdown]
# We could've also created this variable by coercing the given vector using the function `as.factor`

# %%
as.factor(c(1,1,1,2,2,2,3,3,3))
# Out:
# [1] 1 1 1 2 2 2 3 3 3
# Levels: 1 2 3

# %% [markdown]
# **N.B** The labels are always character irrespective of whether their respective values are numeric, character or Boolean etc. in the input vector.

# %% [markdown]
# Many things that apply to usual vectors also apply to factors, e.g. indexing:

# %%
group.factor[1]
# Out:
# [1] 1
# Levels: 1 2 3

# %%
group.factor[1:4]
# Out:
# [1] 1 1 1 2
# Levels: 1 2 3

# %% [markdown]
# However, there are certain operations that you can't perform on factors because these don't make sense, e.g. addition, substraction, multiplication and divition:

# %%
group.factor + 2
# Out:
# Warning message in Ops.factor(group.factor, 2):
# “‘+’ not meaningful for factors”
# [1] NA NA NA NA NA NA NA NA NA

# %%
group.factor / 3
# Out:
# Warning message in Ops.factor(group.factor, 3):
# “‘/’ not meaningful for factors”
# [1] NA NA NA NA NA NA NA NA NA

# %% [markdown]
# ### 5.3.2 - Handy functions
#
# - `levels`:  it yields the different levels.
# - `nlevels`: it yields the count of levels.

# %%
levels(group.factor)
nlevels(group.factor)
# Out:
# [1] "1" "2" "3"
# [1] 3

# %% [markdown]
# With the `levels` function we can also redefine the labels of the factors

# %%
levels(group.factor) <- c("Label1","Label2", "Label3")

group.factor
# Out:
# [1] Label1 Label1 Label1 Label2 Label2 Label2 Label3 Label3 Label3
# Levels: Label1 Label2 Label3

# %% [markdown]
# ## 5.4 - Lists
#
# A list is an R-object that can contain **many different types** of elements inside it like vectors, functions and even another list inside it. It is a very important data structure in R.

# %% [markdown]
# ### 5.4.1 - Initialization
#
# List can be initialized with the function `list` as follows in this example:

# %%
Javi <- list( age = 37, married = TRUE, parents = c("Joseba","Edita"))
Javi
# Out:
# $age
# [1] 37
#
# $married
# [1] TRUE
#
# $parents
# [1] "Joseba" "Edita"

# %% [markdown]
# As you can see, here this list contains three variables of different kinds (and sizes).

# %% [markdown]
# <div class="alert alert-info"> <b>Practice</b>: In the same as we've just seen, create list that contains a variable "name" with your name, "weight" with your weight, "films" with your the name of your favourites films (as a vector), and "soccer_fan" as TRUE or FALSE if you like soccer.  </div>

# %%
#Your answer here

# %% [markdown]
# ### 5.4.2 - Accessing lists
#
# One can access list variables using the operator "$" as follows:

# %%
# This accesses my age
Javi$age
# this tells whether I am married or not
Javi$married
# this shows the names of my parents
Javi$parents
# Out:
# [1] 37
# [1] TRUE
# [1] "Joseba" "Edita"

# %% [markdown]
# ### 5.4.3 - Modifying lists
#
# We can again use the operator "$" to edit an entry value, or add a new entry. For example:

# %%
# Let's modify my age
Javi$age<- 37.5
# Let's add my height as a new entry (in cms)
Javi$height<- 177

Javi
# Out:
# $age
# [1] 37.5
#
# $married
# [1] TRUE
#
# $parents
# [1] "Joseba" "Edita"
#
# $height
# [1] 177

# %% [markdown]
# ## 5.5 - Data Frames
#
# Data frames are possibly the most important data structures in R.
#
# Why is it so important? Because it's how usually most tabular data are represented, and when you work with data, you'll likely have this form of data.
#
# A data frame is a special type of list where every entry has same length, that is, a data frame is a like "rectangular" list.

# %% [markdown]
# ### 5.5.1 - Intialization
#
# Data frames are initialized like lists, but using the function `data.frame` instead.

# %%
age <- c(17, 19, 21, 37, 22, 35, 18)
gender<-factor(c("female", "female", "male", "female", "male", "female", "male"))
score <- c(12, 10, 11, 15, 12, 10, 11)

my.dataframe <- data.frame ( age=age, gender=gender, score=score )

my.dataframe
# Out:
#   age gender score
# 1 17  female 12
# 2 19  female 10
# 3 21  male   11
# 4 37  female 15
# 5 22  male   12
# 6 35  female 10
# 7 18  male   11

# %% [markdown]
# As we said a few moments ago, data frames are usually used to represent tabular data. This is the kind of data you are usually given in the form of an external file. Data contained in external files can be  imported into R in the form of data frames using the functions `read.csv` and `read.table`:

# %% [markdown]
# <div class="alert alert-info"> <b>Practice</b>: The dataset below contains 3 measures of ability: SATV, SATQ, ACT (from Arel-Bundock V (2023). *Rdatasets: A collection of datasets originally distributed in various R packages.*). Then, use the function <b>read.csv</b> to load it (Just pass the whole url as an argument to this function). Save the result to a variable called "dat", for example. </div>
#
# url dataset: https://vincentarelbundock.github.io/Rdatasets/csv/psych/sat.act.csv

# %%
# Your code here

# %% [markdown]
# ### 5.5.2 - Access and modifying
#
# Like with lists, the operator "$" is used to access and modify data frames

# %%
# This shows the age variable
my.dataframe$age
# Out:
# [1] 17 19 21 37 22 35 18

# %%
# This adds an entry called "var1", with the same value in all its elements 
my.dataframe$var1<-1
my.dataframe
# Out:
#   age gender score var1
# 1 17  female 12    1
# 2 19  female 10    1
# 3 21  male   11    1
# 4 37  female 15    1
# 5 22  male   12    1
# 6 35  female 10    1
# 7 18  male   11    1

# %%
# This adds an entry called "var2", with different values
my.dataframe$var2<-c(1:7)
my.dataframe
# Out:
#   age gender score var1 var2
# 1 17  female 12    1    1
# 2 19  female 10    1    2
# 3 21  male   11    1    3
# 4 37  female 15    1    4
# 5 22  male   12    1    5
# 6 35  female 10    1    6
# 7 18  male   11    1    7

# %% [markdown]
# ### 5.5.3 - Handy functions
#
# - `head`: it displays the first six lines (this number can be modified with the argument "n") of the data frame.

# %%
head(my.dataframe)
# Out:
#   age gender score var1 var2
# 1 17  female 12    1    1
# 2 19  female 10    1    2
# 3 21  male   11    1    3
# 4 37  female 15    1    4
# 5 22  male   12    1    5
# 6 35  female 10    1    6

# %%
head(my.dataframe, n = 2)
# Out:
#   age gender score var1 var2
# 1 17  female 12    1    1
# 2 19  female 10    1    2

# %% [markdown]
# - `tail`: the same as `head`, but displaying the last six lines

# %%
tail(my.dataframe)
# Out:
#   age gender score var1 var2
# 2 19  female 10    1    2
# 3 21  male   11    1    3
# 4 37  female 15    1    4
# 5 22  male   12    1    5
# 6 35  female 10    1    6
# 7 18  male   11    1    7

# %%
tail(my.dataframe, n=2)
# Out:
#   age gender score var1 var2
# 6 35  female 10    1    6
# 7 18  male   11    1    7

# %% [markdown]
# - `names`: it show the names all variables stored in the data frame.

# %%
names(my.dataframe)
# Out:
# [1] "age"    "gender" "score"  "var1"   "var2"

# %% [markdown]
# - `str`: it returns the structure of data frame - name, type and preview of data in each column.

# %%
str(my.dataframe)
# Out:
# 'data.frame':	7 obs. of  5 variables:
#  $ age   : num  17 19 21 37 22 35 18
#  $ gender: Factor w/ 2 levels "female","male": 1 1 2 1 2 1 2
#  $ score : num  12 10 11 15 12 10 11
#  $ var1  : num  1 1 1 1 1 1 1
#  $ var2  : int  1 2 3 4 5 6 7

# %% [markdown]
# And these are the same that we saw before (You're free to try them out):
#
# - `dim`: it returns the dimensions of data frame (i.e. number of rows and number of columns)
# - `nrow`: it returns the number of rows
# - `ncol`: it returns the number of columns

# %% [markdown]
# # 6- Packages

# %% [markdown]
# As in many languages, it is common to have to use pieces of code (functions, data, etc) many times. Here is when the concept of a **package** comes in play.
#
# Basically, a package is just a collection of functions, datasets and other R objects that are all grouped together under a common name. Some packages come installed by default with R, but a vast majority of the R packages will need to be installed manually from the Internet. The large number of packages available for R, and the ease of installing and using them, has been cited as a major factor driving the widespread adoption of the language in data science.
#
# In order to use a package we need to load it, that is, we need to make their functions, data, etc available and visible to our enviroment. (**N.B.** The package needs to be installed in our computer. Visit this to know how to install a package)

# %% [markdown]
# ## 6.2 Loading a package
#
# In order to load a library, we just need to call the function `library`. Let's see an example using probably one of the most important libraries in R, ggplot2 (https://ggplot2.tidyverse.org)

# %%
library(ggplot2)
# Out:
# Registered S3 methods overwritten by 'tibble':
#   method     from
#   format.tbl pillar
#   print.tbl  pillar
#
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
#
#
# Attaching package: ‘ggplot2’
#
#
# The following objects are masked from ‘package:psych’:
#
#     %+%, alpha

# %% [markdown]
# # 7- SOME PROGRAMMING BASICS
#
# At some point, in order to perform and implement complex tasks, you may end up having to write a computer program. As a consequence, it is recommendable that you get familiar with the most very basic programming operations that you can perform in R.

# %% [markdown]
# ## 7.1. Conditional statements (IF, IF...ELSE)
#
# A conditional statement is an operation that allows you to switch between different possible commands depending on a specified condition that is specified by the programmer.
#
# The most prominent of example of a conditional statement is the if statement, and the accompanying else statement.
#
# Howver, before jumping to how to define an if statement, let's go over the different logical operations in R. These will give you as a result boolean, that is, a TRUE or FALSE value:

# %% [markdown]
# - "==" : Equal (e.g. x==y)
# - "!=" : Not equal (e.g. x!=y)
# - ">" : Greater than	(e.g. x > y)
# - "<" : Less than (x < y)
# - ">=" : Greater than or equal to (e.g. x >= y)
# - "<=" : Less than or equal to (e.g. x => y)

# %%
x<-5
y<-7

# x equal to y
x==y
# x not equal to y
x!=y
# x greater that y
x>y
# x smaller that y
x<y
# x greater than or equal to y
x>=y
# x smaller than or equal to y
x<=y
# Out:
# [1] FALSE
# [1] TRUE
# [1] FALSE
# [1] TRUE
# [1] FALSE
# [1] TRUE

# %% [markdown]
# The basic format of an if statement in R is as follows:
#
# ```
# if ( CONDITION ) {
# STATEMENT1
# STATEMENT2
# ETC
# }
# ````

# %%
x=5
if( x > 4){
    print("x greater than 4")
}
# Out:
# [1] "x greater than 4"

# %% [markdown]
# As you can see, If the condition within the parenthesis is true, then R will execute the statements contained in the curly braces. If the condition is false, then it does nothing.
#
# If you want to perform an operation when the condition within if is not satisfied, you can extend the if statement to include an else statement as well, leading to the following syntax:
#
# ```
# if ( CONDITION ) {
# STATEMENT1
# STATEMENT2
# ETC
# } else {
# STATEMENT3
# STATEMENT4
# ETC
# }
# ```

# %%
x<-2
if( x > 4){
    print("x greater than 4")
} else {
    print("x smaller than 4")
}
# Out:
# [1] "x smaller than 4"

# %% [markdown]
# Finally, a handy way of applying an if/else statement to several elements in a vector is by the `ifelse` function:

# %%
# input vector
x <- c(12, 9, 23, 14, 20, 1, 5)

# ifelse() function to determine odd/even numbers
ifelse(x %% 2 == 0, "EVEN", "ODD")
# Out:
# [1] "EVEN" "ODD"  "ODD"  "EVEN" "EVEN" "ODD"  "ODD"

# %% [markdown]
# ## 7.2. Loops
#
# Loops are block of codes (i.e., a sequence of commands) that will execute over and over again until some termination criterion is met.

# %% [markdown]
# ## 7.2.1 while loop
#
# A while loop is a simple thing. The basic format of the loop looks like this:
#
# ```
# while ( CONDITION ) {
# STATEMENT1
# STATEMENT2
# ETC
# }
# ```
#
# Whenever R encounters a while statement, it checks to see if the condition within the parenthesis is TRUE. If it is, then R carries on executing all of the commands inside the curly brackets. When it gets to the
# bottom of those statements, it moves back up to the while statement. Then, it checks to see if the condition is TRUE. If it is, then it executes everything again. And it does so until the condition turns out to be FALSE, for which it exits the loop.

# %%
x <- 0
while ( x < 100 ) {
x <- x + 17
print( x )
}
print("I exited the loop, yeah!")
# Out:
# [1] 17
# [1] 34
# [1] 51
# [1] 68
# [1] 85
# [1] 102
# [1] "I exited the loop, yeah!"

# %% [markdown]
# ## 7.2.2 for loop
#
# The for loop is similar to the while loop, but instead of running while a condition is TRUE, it runs a fixed number of iterations. The sintax in R is as follows:
#
# ```
# for ( VAR in VECTOR ) {
# STATEMENT1
# STATEMENT2
# ETC
# }
# ```
#
# The for loop will execute the block of code within the curly brackets, but iterations will run through the different elements in the VECTOR and setting the value of VAR to that particular vector element.

# %%
for ( i in c(1:5) ) {
print( "hola caracola" )
}
# Out:
# [1] "hola caracola"
# [1] "hola caracola"
# [1] "hola caracola"
# [1] "hola caracola"
# [1] "hola caracola"

# %%
for ( i in c(1:5) ) {
    
print( i)
}
# Out:
# [1] 1
# [1] 2
# [1] 3
# [1] 4
# [1] 5

# %% [markdown]
# <div class="alert alert-info"> <b>Practice</b>: Create a variable "x" and set a value 0 to it. Then, create a loop that iterates a vector from 1 to 10. In each iteration update the value of x by adding the value of each element of the vector. </div>

# %%
# Write your response here

# %% [markdown]
# ## 7.3 - Write your own functions
#
# We have already introduced the concept of functions and how to use them. However, we have only used predefined functions. What if we want to write our own functions? This can be helpful in case we want to perform a specific computation.
#
#
# The syntax that you use to create a function is as follows:
#
# ```
# FNAME <- function ( ARG1, ARG2, ETC ) {
# STATEMENT1
# STATEMENT2
# ETC
# return( VALUE )
# }
# ```
#
# This will create a function with the name fname, which has arguments arg1, arg2 and so forth.
# Whenever the function is called, R executes the statements in the curly braces, and then outputs the contents of
# value to the user. To note, only the final results in the value are returned. Everything that was set or stored within the function will no be visible after the function is called.

# %%
# Example: This creates a function that multiplies a number by 3
triple <- function(x) {
y <- x*3
return(y)
}

# %%
x<-3
triple(x)
# Out:
# [1] 9

# %% [markdown]
# <div class="alert alert-info"> <b>Practice</b>: Create a function "myabs" that returns the absolute value of a given number. Test that it works as expected. </div>

# %%
# Write your response here

# %% [markdown]
# <div class="alert alert-info"> <b>Practice</b>: Create a function "mysquare", of two arguments, such that it takes the square of the first one, and then it adds the second one to it. Set the second argument to take the value 2 as default. Test it. </div>

# %% [markdown]
# # 8- Miscellaneous: some special Values

# %% [markdown]
# *Infinity*: It corresponds to a value that is infinitely large. You can also have -Inf. This is the value you'd obtain by dividing a number by 0. R has a built-in value for this, `Inf`

# %%
1/0
# Out:
# [1] Inf

# %%
-1/0
# Out:
# [1] -Inf

# %%
Inf
# Out:
# [1] Inf

# %% [markdown]
# *Not a Number*. The special value of NaN is short for “not a number”, and it’s basically a reserved keyword that means “there isn’t a mathematically defined number for this”. In R, this is reserved for the value `NaN`

# %%
0/0
# Out:
# [1] NaN

# %%
NaN
# Out:
# [1] NaN

# %% [markdown]
# *Not available*. It indicates that the value that is "supposed" to be stored here is missing. This is a typical situation when you read a dataset and observations miss values for some specific measured variables. In R, this is kind of value takes the keyword `NA`

# %%
NA
# Out:
# [1] NA

# %% [markdown]
# *No value*. It takes the keyword `NULL` in R and it asserts that the variable genuinely has no value whatsoever.

# %%
NULL
# Out:
# NULL

# %% [markdown]
# # Resources for R
#
# - [Base R cheatsheet](https://iqss.github.io/dss-workshops/R/Rintro/base-r-cheat-sheet.pdf)
